# %% [markdown]
# #  CRM Data Analysis Project
#
# ##  Project Overview
# This project focuses on analyzing CRM (Customer Relationship Management) data to extract insights about customer behavior, engagement, and revenue contribution.
#
# The goal is to:
# - Clean and preprocess raw CRM data
# - Perform exploratory data analysis (EDA)
# - Identify high-value customers
# - Prepare data for Power BI dashboard visualization
#
# ---
#
# ##  Objectives
# - Analyze revenue distribution
# - Segment customers by value
# - Understand engagement behavior
# - Prepare clean dataset for visualization

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../data/raw/CRM_Donor_Simulation_Dataset (2).csv")

# Preview data
df.head()
# Out:
#   DonorID FirstName  LastName                         Email  \
# 0  D00001  Danielle  Anderson            tina69@salazar.com
# 1  D00002     Angel      Hart         garciatyler@gmail.com
# 2  D00003    Joshua     Stone              ywoods@gmail.com
# 3  D00004   Jeffrey     Welch  johnsonkimberly@ferguson.com
# 4  D00005      Jill   Vasquez      hughesnicholas@gmail.com
#
#                 Phone               City State  ZipCode LastDonationDate  \
# 0  (716)033-8417x8760          New Ethan    AK     9539         9/3/2024
# 1       (874)907-2648   West Ashleymouth    MS    49618         5/6/2022
# 2  105.039.1678x12883     East Stephanie    NJ     6600        1/21/2023
# 3    939.859.3082x278  South Andrewshire    SD    22434        1/26/2023
# 4        469-539-5369          Moorestad    DC    16142         5/5/2022
#
#    TotalGifts  TotalAmountDonated EventParticipation  EngagementScore
# 0          10             8481.55                Yes               56
# ...

# %%
# Check dataset structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DonorID             5000 non-null   object
#  1   FirstName           5000 non-null   object
#  2   LastName            5000 non-null   object
#  3   Email               5000 non-null   object
#  4   Phone               5000 non-null   object
#  5   City                5000 non-null   object
#  6   State               5000 non-null   object
#  7   ZipCode             5000 non-null   int64
#  8   LastDonationDate    5000 non-null   object
#  9   TotalGifts          5000 non-null   int64
#  10  TotalAmountDonated  5000 non-null   float64
#  11  EventParticipation  5000 non-null   object
#  12  EngagementScore     5000 non-null   int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 507.9+ KB

# %%
# Check missing values
df.isnull().sum()
# Out:
# DonorID               0
# FirstName             0
# LastName              0
# Email                 0
# Phone                 0
# City                  0
# State                 0
# ZipCode               0
# LastDonationDate      0
# TotalGifts            0
# TotalAmountDonated    0
# EventParticipation    0
# EngagementScore       0
# dtype: int64

# %% [markdown]
# ##  Data Inspection Summary
#
# ###  Commands Used
#
# - `df.info()`
#   Used to understand:
#   - Number of rows and columns
#   - Data types of each column
#   - Non-null values (to check missing data)
#
# - `df.isnull().sum()`
#   Used to check:
#   - Missing values in each column
#
#
#
# ###  Dataset Overview
#
# - The dataset contains **5000 rows** and **13 columns**
# - All columns have **0 missing values**
# - This means the dataset is **complete and clean**
#
#
# ###  What the Data Looks Like
#
# - Contains **donor/customer information** such as:
#   - Name, email, phone
#   - Location (city, state)
#   - Donation history
#
# - Includes key business fields:
#   - `TotalAmountDonated` → total revenue
#   - `TotalGifts` → number of donations
#   - `EngagementScore` → customer engagement level
#   - `LastDonationDate` → last activity date
#
#
#
# ###  Data Type Observation
#
# - Most text fields are correctly stored as **object type**
# - Numeric fields are correct
#
#  Issue:
# - `LastDonationDate` is stored as **object (text)**
# - But it represents a **date**
#
#
#
# ###  Required Action
#
# - Convert `LastDonationDate` to **datetime format**
#
#
#
# ###  Why This Is Needed
#
# - To analyze **time trends** (monthly, yearly donations)
# - To build **Power BI date-based charts**
# - To improve **data accuracy and usability**
#
#
#
# ###  Conclusion
#
# The dataset is well-structured and has no missing values.
# Only **minor data type correction** is needed before analysis.
